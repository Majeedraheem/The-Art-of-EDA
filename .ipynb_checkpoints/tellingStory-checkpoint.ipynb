# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib  inline

# %%
df_insurance=pd.read_csv("/Users/mac/Desktop/Npower Course /Data_Visualiazition /To_github/insurance.csv")

# %%
df_insurance.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df_insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df_insurance.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df_insurance.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df_insurance.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
df_insurance["charges_scaled"]= scaler.fit_transform(df_insurance[['charges']])

# %%
df_insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  \
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#
#    charges_scaled
# 0        0.298584
# 1       -0.953689
# 2       -0.728675
# 3        0.719843
# 4       -0.776802

# %% [markdown]
# #### Bmi is measurement used to categorize weight status according to ranges, typically:
#
#     * Underweight: BMI < 18.5
#     * Normal weight: BMI 18.5–24.9
#     * Overweight: BMI 25–29.9
#     * Obesity: BMI ≥ 30
#     def weight_status_fun(df):
#     # Define the conditions
#     df['weight_status'] = 'Unknown'  # Default value for safety
#
#     df.loc[df['bmi'] < 18.5, 'weight_status'] = 'UnderWeight'
#     df.loc[(df['bmi'] >= 18.5) & (df['bmi'] < 24.9), 'weight_status'] = 'NormalWeight'
#     df.loc[(df['bmi'] >= 25) & (df['bmi'] < 29.9), 'weight_status'] = 'OverWeight'
#     df.loc[df['bmi'] >= 30, 'weight_status'] = 'Obesity'
#
#     return df

# %%
def get_weight_status(bmi):
    if bmi < 18.5:
        return 'UnderWeight'
    elif 18.5 <= bmi < 24.9:
        return 'NormalWeight'
    elif 25 <= bmi < 29.9:
        return 'OverWeight'
    else:  # bmi >= 30
        return 'Obesity'

# %%
df_insurance["weight_status"]=df_insurance["bmi"].apply(get_weight_status)

# %%
df_insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  \
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#
#    charges_scaled weight_status
# 0        0.298584    OverWeight
# 1       -0.953689       Obesity
# 2       -0.728675       Obesity
# 3        0.719843  NormalWeight
# 4       -0.776802    OverWeight

# %%
df_insurance=df_insurance['charges'].round(1)
# Out:
# 0       16884.9
# 1        1725.6
# 2        4449.5
# 3       21984.5
# 4        3866.9
#          ...
# 1333    10600.5
# 1334     2206.0
# 1335     1629.8
# 1336     2007.9
# 1337    29141.4
# Name: charges, Length: 1338, dtype: float64

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
df_insurance['charges']=df_insurance['charges'].round(1)

# %%
df_insurance
# Out:
#       age     sex     bmi  children smoker     region  charges  \
# 0      19  female  27.900         0    yes  southwest  16884.9
# 1      18    male  33.770         1     no  southeast   1725.6
# 2      28    male  33.000         3     no  southeast   4449.5
# 3      33    male  22.705         0     no  northwest  21984.5
# 4      32    male  28.880         0     no  northwest   3866.9
# ...   ...     ...     ...       ...    ...        ...      ...
# 1333   50    male  30.970         3     no  northwest  10600.5
# 1334   18  female  31.920         0     no  northeast   2206.0
# 1335   18  female  36.850         0     no  southeast   1629.8
# 1336   21  female  25.800         0     no  southwest   2007.9
# 1337   61  female  29.070         0    yes  northwest  29141.4
#
#       charges_scaled weight_status
# 0           0.298584    OverWeight
# 1          -0.953689       Obesity
# 2          -0.728675       Obesity
# 3           0.719843  NormalWeight
# 4          -0.776802    OverWeight
# ...              ...           ...
# 1333       -0.220551       Obesity
# 1334       -0.914002       Obesity
# 1335       -0.961596       Obesity
# 1336       -0.930362    OverWeight
# 1337        1.311053    OverWeight
#
# [1338 rows x 9 columns]

# %%
df_insurance["charges_thounds"]=df_insurance["charges"]/1000

# %%
df_insurance.head()
# Out:
#    age     sex     bmi  children smoker     region  charges  charges_scaled  \
# 0   19  female  27.900         0    yes  southwest  16884.9        0.298584
# 1   18    male  33.770         1     no  southeast   1725.6       -0.953689
# 2   28    male  33.000         3     no  southeast   4449.5       -0.728675
# 3   33    male  22.705         0     no  northwest  21984.5        0.719843
# 4   32    male  28.880         0     no  northwest   3866.9       -0.776802
#
#   weight_status  charges_thounds
# 0    OverWeight          16.8849
# 1       Obesity           1.7256
# 2       Obesity           4.4495
# 3  NormalWeight          21.9845
# 4    OverWeight           3.8669

# %%
fig , ax =plt.subplots(figsize=(10, 10))
ax.scatter(df_insurance['age'],df_insurance['charges'],label='customer')
ax.set_title("The Age vs Charges")
ax.set_ylabel("Insurance Charges")
ax.set_xlabel("Customer Age")
#plt.legend("Customers")
ax.legend(loc='upper left', bbox_to_anchor=(0.5, 0.5))
plt.grid(True)
plt.show()
